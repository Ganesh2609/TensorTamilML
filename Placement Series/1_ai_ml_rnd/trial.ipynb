# %%
from dataset import ParametricDataset, get_dataloaders

# %%
csv_path = 'xy_data.csv'
dataset = ParametricDataset(csv_path=csv_path)

# %%
dataset[0]
# Out:
# {'t': tensor(6.0360), 'x': tensor(88.3645), 'y': tensor(57.7844)}

# %%
train_loader, test_loader = get_dataloaders(csv_path)

# %%
next(iter(train_loader))
# Out:
# {'t': tensor([10.2092, 45.1059, 39.1699, 56.2225, 39.2418, 38.9900, 40.1772, 14.9221,
#          16.3251, 51.2578, 36.5077, 44.7102, 31.6509, 16.7928, 13.6629, 27.7295,
#          27.6935, 35.0686,  8.8421, 32.7662, 57.1939, 56.2585, 19.9947, 53.0566,
#          13.7708, 38.2345, 46.5450, 30.9674, 31.3991, 15.3178, 50.5383, 36.4717]),
#  'x': tensor([105.7889, 103.5527,  82.0772,  89.2085, 100.7427,  91.8219,  67.9528,
#           95.9458,  98.8839,  91.9769,  94.7395,  70.1631,  69.4958,  89.3923,
#           64.8481,  95.2834,  74.4981,  70.1097,  71.5211, 107.2096,  91.5278,
#           84.6565, 108.5877,  65.0723,  75.2240,  70.6262,  76.1508, 106.3984,
#           80.5776,  86.4289,  91.9241,  89.3645]),
#  'y': tensor([65.8946, 66.6676, 57.7250, 58.3757, 67.9906, 65.2633, 47.8977, 69.6696,
#          68.8354, 65.8482, 69.5899, 48.9213, 48.5145, 58.5587, 47.3370, 69.6753,
#          54.7404, 48.8848, 50.1444, 65.8028, 64.0268, 57.3808, 66.5864, 47.3657,
# ...

# %%
from model import ParametricModel

# %%
model = ParametricModel()

# %%
import torch

model(t=torch.tensor(6.1, dtype=torch.float32))
# Out:
# (tensor(56.1743, grad_fn=<AddBackward0>),
#  tensor(42.1507, grad_fn=<AddBackward0>))
